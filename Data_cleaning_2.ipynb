# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#loaded data as well as airport data with information about the airports from https://datahub.io/core/airport-codes 

df = pd.read_csv('data/Train.csv')
airport_data = pd.read_csv('data/airport_data.csv', dtype={'continent': 'string'}, na_values=[''])
airport_data['continent'].fillna('NA', inplace=True)
df.columns = df.columns.str.lower()

# %%
#delete rows with status DEL, SCH, RTR, DEP
df = df[~df['status'].isin(['DEL', 'SCH', 'RTR', 'DEP'])]

# %%
#create new column airline
df['airline'] = df['ac'].apply(lambda x: x[:2])

# %%
# Convert datop (date of flight) to datetime
df['datop'] = pd.to_datetime(df['datop'], format="%Y-%m-%d", errors='coerce')

# Extract time from scheduled time departure (std) and confert to datetime
df['std'] = pd.to_datetime(df['std']).dt.strftime('%H:%M:%S')

# Extract time from scheduled time arrival (sta) and convert to datetime
df['sta'] = pd.to_datetime(df['sta'], format='%Y-%m-%d %H.%M.%S').dt.strftime('%H:%M:%S')

# %%
df.head()
# Out:
#            id      datop     fltid depstn arrstn       std       sta status
# 0  train_id_0 2016-01-03  TU 0712     CMN    TUN  10:30:00  12:55:00    ATA  \
# 1  train_id_1 2016-01-13  TU 0757     MXP    TUN  15:05:00  16:55:00    ATA
# 2  train_id_2 2016-01-16  TU 0214     TUN    IST  04:10:00  06:45:00    ATA
# 3  train_id_3 2016-01-17  TU 0480     DJE    NTE  14:10:00  17:00:00    ATA
# 4  train_id_4 2016-01-17  TU 0338     TUN    ALG  14:30:00  15:50:00    ATA
#
#           ac  target airline
# 0  TU 32AIMN   260.0      TU
# 1  TU 31BIMO    20.0      TU
# 2  TU 32AIMN     0.0      TU
# 3  TU 736IOK     0.0      TU
# 4  TU 320IMU    22.0      TU

# %%
# Extract day of the week
df['day_of_week'] = df['datop'].dt.day_name()

# %%
#Extract morning, midday, afternoon, evening, night from scheduled time departure (std) and scheduled time arrival (sta)
def get_time_of_day(time_str):
    hour = int(time_str.split(':')[0])
    if 0 <= hour < 6:
        return 'night'
    elif 6 <= hour < 12:
        return 'morning'
    elif 12 <= hour < 14:
        return 'midday'
    elif 14 <= hour < 17:
        return 'afternoon'
    elif 17 <= hour < 21:
        return 'evening'
    else:
        return 'night'

df['time_day_std'] = df['std'].apply(get_time_of_day)
df['time_day_sta'] = df['sta'].apply(get_time_of_day)

# %%
df.head()
# Out:
#            id      datop     fltid depstn arrstn       std       sta status
# 0  train_id_0 2016-01-03  TU 0712     CMN    TUN  10:30:00  12:55:00    ATA  \
# 1  train_id_1 2016-01-13  TU 0757     MXP    TUN  15:05:00  16:55:00    ATA
# 2  train_id_2 2016-01-16  TU 0214     TUN    IST  04:10:00  06:45:00    ATA
# 3  train_id_3 2016-01-17  TU 0480     DJE    NTE  14:10:00  17:00:00    ATA
# 4  train_id_4 2016-01-17  TU 0338     TUN    ALG  14:30:00  15:50:00    ATA
#
#           ac  target airline day_of_week time_day_std time_day_sta
# 0  TU 32AIMN   260.0      TU      Sunday      morning       midday
# 1  TU 31BIMO    20.0      TU   Wednesday    afternoon    afternoon
# 2  TU 32AIMN     0.0      TU    Saturday        night      morning
# 3  TU 736IOK     0.0      TU      Sunday    afternoon      evening
# 4  TU 320IMU    22.0      TU      Sunday    afternoon    afternoon

# %%
# Searched for missing information in airport_data and added to airport_data file
airport_info = [
    {'iata_code': 'AMM', 'continent': 'AS', 'iso_country': 'JO', 'type': 'large_airport'},
    {'iata_code': 'BEY', 'continent': 'AS', 'iso_country': 'LB', 'type': 'large_airport'},
    {'iata_code': 'DOH', 'continent': 'AS', 'iso_country': 'QA', 'type': 'large_airport'},
    {'iata_code': 'EBL', 'continent': 'AS', 'iso_country': 'IQ', 'type': 'large_airport'},
    {'iata_code': 'IEV', 'continent': 'EU', 'iso_country': 'UA', 'type': 'medium_airport'},
    {'iata_code': 'JED', 'continent': 'AS', 'iso_country': 'SA', 'type': 'large_airport'},
    {'iata_code': 'KBP', 'continent': 'EU', 'iso_country': 'UA', 'type': 'large_airport'},
    {'iata_code': 'KRR', 'continent': 'EU', 'iso_country': 'RU', 'type': 'large_airport'},
    {'iata_code': 'LED', 'continent': 'EU', 'iso_country': 'RU', 'type': 'large_airport'},
    {'iata_code': 'MED', 'continent': 'AS', 'iso_country': 'SA', 'type': 'medium_airport'},
    {'iata_code': 'SKX', 'continent': 'EU', 'iso_country': 'RU', 'type': 'small_airport'},
    {'iata_code': 'SVO', 'continent': 'EU', 'iso_country': 'RU', 'type': 'large_airport'},
    {'iata_code': 'SXF', 'continent': 'EU', 'iso_country': 'DE', 'type': 'large_airport'},
    {'iata_code': 'VKO', 'continent': 'EU', 'iso_country': 'RU', 'type': 'large_airport'},
    {'iata_code': 'VOG', 'continent': 'EU', 'iso_country': 'RU', 'type': 'medium_airport'}
]

# Convert airport_info to DataFrame
new_info_df = pd.DataFrame(airport_info)

# Update existing rows or append new rows
for index, row in new_info_df.iterrows():
    iata_code = row['iata_code']
    if iata_code in airport_data['iata_code'].values:
        airport_data.loc[airport_data['iata_code'] == iata_code, ['continent', 'iso_country', 'type']] = row[['continent', 'iso_country', 'type']]
    else:
        airport_data = pd.concat([airport_data, row.to_frame().T], ignore_index=True)

airport_data.head(20)
# Out:
#    ident           type                               name  elevation_ft
# 0    00A       heliport                  Total RF Heliport          11.0  \
# 1   00AA  small_airport               Aero B Ranch Airport        3435.0
# 2   00AK  small_airport                       Lowell Field         450.0
# 3   00AL  small_airport                       Epps Airpark         820.0
# 4   00AN  small_airport               Katmai Lodge Airport          80.0
# 5   00AS  small_airport                     Fulton Airport        1100.0
# 6   00AZ  small_airport                     Cordes Airport        3810.0
# 7   00CA  small_airport            Goldstone (GTS) Airport        3038.0
# 8   00CL  small_airport                Williams Ag Airport          87.0
# 9   00CN       heliport    Kitchen Creek Helibase Heliport        3350.0
# 10  00FA  small_airport                Grass Patch Airport          53.0
# 11  00FL  small_airport                  River Oak Airport          35.0
# 12  00GA  small_airport                   Lt World Airport         700.0
# 13  00GE       heliport                   Caffrey Heliport         957.0
# 14  00HI       heliport                 Kaupulehu Heliport          43.0
# 15  00ID  small_airport               Delta Shores Airport        2064.0
# 16  00IG  small_airport                      Goltl Airport        3359.0
# 17  00IL  small_airport                     Hammer Airport         840.0
# 18  00IN       heliport    St Mary Medical Center Heliport         634.0
# 19  00IS  small_airport  Hayenga's Cant Find Farms Airport         820.0
#
#    continent iso_country iso_region  municipality icao_code iata_code
# 0         NA          US      US-PA      Bensalem       NaN       NaN  \
# 1         NA          US      US-KS         Leoti       NaN       NaN
# 2         NA          US      US-AK  Anchor Point       NaN       NaN
# 3         NA          US      US-AL       Harvest       NaN       NaN
# 4         NA          US      US-AK   King Salmon       NaN       NaN
# 5         NA          US      US-OK          Alex       NaN       NaN
# 6         NA          US      US-AZ        Cordes       NaN       NaN
# 7         NA          US      US-CA       Barstow       NaN       NaN
# 8         NA          US      US-CA         Biggs       NaN       NaN
# 9         NA          US      US-CA   Pine Valley       NaN       NaN
# 10        NA          US      US-FL      Bushnell       NaN       NaN
# 11        NA          US      US-FL    Okeechobee       NaN       NaN
# 12        NA          US      US-GA      Lithonia       NaN       NaN
# 13        NA          US      US-GA         Hiram       NaN       NaN
# 14        OC          US      US-HI   Kailua-Kona       NaN       NaN
# 15        NA          US      US-ID    Clark Fork       NaN       NaN
# 16        NA          US      US-KS      McDonald       NaN       NaN
# 17        NA          US      US-IL          Polo       NaN       NaN
# 18        NA          US      US-IN        Hobart       NaN       NaN
# 19        NA          US      US-IL         Kings       NaN       NaN
#
#    gps_code local_code                              coordinates
# 0      K00A        00A                    40.070985, -74.933689
# 1      00AA       00AA                   38.704022, -101.473911
# 2      00AK       00AK                   59.947733, -151.692524
# 3      00AL       00AL    34.86479949951172, -86.77030181884766
# 4      00AN       00AN                   59.093287, -156.456699
# 5      00AS       00AS                  34.9428028, -97.8180194
# 6      00AZ       00AZ  34.305599212646484, -112.16500091552734
# 7      00CA       00CA                    35.35474, -116.885329
# 8      00CL       00CL                   39.427188, -121.763427
# 9      00CN       00CN                 32.7273736, -116.4597417
# 10     00FA       00FA    28.64550018310547, -82.21900177001953
# 11     00FL       00FL   27.230899810791016, -80.96920013427734
# 12     00GA       00GA    33.76750183105469, -84.06829833984375
# 13     00GE       00GE                    33.887982, -84.736983
# 14     00HI       00HI                   19.832881, -155.978347
# 15     00ID       00ID  48.145301818847656, -116.21399688720703
# 16     00IG       00IG                   39.724028, -101.395994
# 17     00IL       00IL                    41.978401, -89.560402
# 18     00IN       00IN     41.51139831542969, -87.2605972290039
# 19     00IS       00IS     40.02560043334961, -89.1229019165039

# %%
#select interesting columns from airport_data
airport_data = airport_data[['continent', 'iso_country', 'type', 'iata_code']]

# %%
#merge airport data with train data
df = df.merge(airport_data, left_on='depstn', right_on='iata_code', how='left')
df = df.merge(airport_data, left_on='arrstn', right_on='iata_code', how='left', suffixes=('_dep', '_arr'))
df = df.drop(columns=['iata_code_dep', 'iata_code_arr'])
df.head()
# Out:
#            id      datop     fltid depstn arrstn       std       sta status
# 0  train_id_0 2016-01-03  TU 0712     CMN    TUN  10:30:00  12:55:00    ATA  \
# 1  train_id_1 2016-01-13  TU 0757     MXP    TUN  15:05:00  16:55:00    ATA
# 2  train_id_2 2016-01-16  TU 0214     TUN    IST  04:10:00  06:45:00    ATA
# 3  train_id_3 2016-01-17  TU 0480     DJE    NTE  14:10:00  17:00:00    ATA
# 4  train_id_4 2016-01-17  TU 0338     TUN    ALG  14:30:00  15:50:00    ATA
#
#           ac  target airline day_of_week time_day_std time_day_sta
# 0  TU 32AIMN   260.0      TU      Sunday      morning       midday  \
# 1  TU 31BIMO    20.0      TU   Wednesday    afternoon    afternoon
# 2  TU 32AIMN     0.0      TU    Saturday        night      morning
# 3  TU 736IOK     0.0      TU      Sunday    afternoon      evening
# 4  TU 320IMU    22.0      TU      Sunday    afternoon    afternoon
#
#   continent_dep iso_country_dep        type_dep continent_arr iso_country_arr
# 0            AF              MA   large_airport            AF              TN  \
# 1            EU              IT   large_airport            AF              TN
# 2            AF              TN   large_airport            EU              TR
# 3            AF              TN  medium_airport            EU              FR
# 4            AF              TN   large_airport            AF              DZ
#
#          type_arr
# 0   large_airport
# 1   large_airport
# 2   large_airport
# 3  medium_airport
# 4   large_airport

# %%
# Make new features with DP Country = Arr Country
df['is_same_country'] = np.where(df['iso_country_dep'].isna() | df['iso_country_arr'].isna(), np.nan, df['iso_country_dep'] == df['iso_country_arr'])

# %%
df.drop(columns=['datop', 'fltid', 'depstn', 'arrstn', 'std', 'sta', 'ac', 'status'], inplace=True)

# %%
df.head()
# Out:
#            id  target airline day_of_week time_day_std time_day_sta
# 0  train_id_0   260.0      TU      Sunday      morning       midday  \
# 1  train_id_1    20.0      TU   Wednesday    afternoon    afternoon
# 2  train_id_2     0.0      TU    Saturday        night      morning
# 3  train_id_3     0.0      TU      Sunday    afternoon      evening
# 4  train_id_4    22.0      TU      Sunday    afternoon    afternoon
#
#   continent_dep iso_country_dep        type_dep continent_arr iso_country_arr
# 0            AF              MA   large_airport            AF              TN  \
# 1            EU              IT   large_airport            AF              TN
# 2            AF              TN   large_airport            EU              TR
# 3            AF              TN  medium_airport            EU              FR
# 4            AF              TN   large_airport            AF              DZ
#
#          type_arr  is_same_country
# 0   large_airport              0.0
# 1   large_airport              0.0
# 2   large_airport              0.0
# 3  medium_airport              0.0
# 4   large_airport              0.0

# %%
df.to_csv('data/train_cleaned.csv', index=False)

# %% [markdown]
# ### interesting features would be (need to impute some rows, missing values):
# - iso_country_dep
# - iso_country_arr
# - continent_arr
# - continent_dep
# - is_same_country
# - type_dep
# - type_arr
# - days of week
# - airline
